# %%
import numpy as np
import csv
from sklearn.linear_model import LinearRegression
import os

# %%
os.getcwd()
# Out:
# '/Users/crystal.butler/Documents/Code_Projects/NLP/notebooks'

# %%
os.chdir('/Users/crystal.butler/Documents/Code_Projects/NLP/data')
root_dir = os.getcwd()
print(root_dir)
os.listdir()
# Out:
# /Users/crystal.butler/Documents/Code_Projects/NLP/data
# ['FE_pairs_human_rater_scores_nodupes.xlsx',
#  'FE_pairs_human_rater_scores_nodupes_test.csv',
#  'FE_pairs_human_rater_scores_nodupes_train.csv',
#  'FE_pairs_human_rater_scores_nodupes.csv',
#  'FE_pairs_human_rater_scores.csv',
#  'embeddings_context_vocab',
#  'FE_vocab_study.txt',
#  'FE_pairs.csv',
#  'roberta_layer8_CC_ab_FEvocab.txt']

# %%
with open('FE_pairs_human_rater_scores_nodupes_train.csv', newline='') as train:
    train_reader = csv.reader(train, delimiter=',')
    for row in train_reader:
        word_one, word_two, score = row[0], row[1], row[2]
        print(word_one, word_two, score)
# Out:
# ﻿disdainful excited 0.571428571
# alarmed distressed 7.733333333
# astounded surprised 9.142857143
# miffed fearful 1.833333333
# sorrowful pleased 0.214285714
# aghast mad 6.266666667
# distressed pissed 7.333333333
# frustrated frustrated 10
# stunned worried 4.466666667
# pissed fearful 4.066666667
# confused startled 6.214285714
# upset scared 5.533333333
# rejected offended 5.8
# distressed frustrated 7.2
# stunned anxious 4.066666667
# stupefied furious 3.2
# mad disappointed 6.133333333
# infuriated mournful 3.066666667
# bored confused 1.933333333
# neutral bored 5.571428571
# concerned sad 4.2
# resentful scornful 7.866666667
# furious joyful 0
# frightened excited 2.133333333
# dissatisfied distressed 6.25
# bored joyful 0.4
# perplexed dissatisfied 3.866666667
# disgusted repelled 9.083333333
# incensed revolted 7
# revolted irate 6.466666667
# terrified hostile 5.461538462
# amazed perplexed 6
# scared interested 0.785714286
# disappointed terrified 2.933333333
# astonished saddened 3.133333333
# mournful mad 3.333333333
# hostile revolted 6.714285714
# miffed concerned 3.5
# dismayed aghast 6.714285714
# excited incensed 2.533333333
# interested neutral 1.4
# happy delighted 9.533333333
# discouraged bothered 6
# uncertain startled 4.466666667
# sad dissatisfied 6.533333333
# delighted upset 0
# scornful depressed 4.866666667
# repulsed hurt 5.266666667
# pissed displeased 8
# mad displeased 8.4
# angry perplexed 2.8
# resentful bewildered 2.666666667
# concerned frightened 5.2
# amused irate 0.466666667
# repelled aghast 5.4
# suspicious amused 0.8
# surprised incensed 3.214285714
# pleased scared 0.533333333
# bothered cheerful 0.571428571
# outraged interested 1.266666667
# astounded disgusted 2.733333333
# startled resentful 1.8
# awed dejected 0.785714286
# offended surprised 1.769230769
# satisfied skeptical 0.866666667
# hostile rejected 4.466666667
# mournful doubtful 3.2
# cheerful satisfied 6.533333333
# joyful annoyed 0.333333333
# amazed infuriated 0.571428571
# astonished appalled 4.4
# hurt bored 1.2
# saddened uncertain 3.533333333
# amused disdainful 0.666666667
# saddened astounded 2.6
# appalled alarmed 6.692307692
# interested amused 6.857142857
# scornful neutral 0.384615385
# doubtful rejected 5.2
# depressed angry 3.666666667
# bewildered appalled 5.466666667
# scared resentful 2.6
# awed awed 10
# sad bewildered 3.357142857
# repelled disbelieving 4.642857143
# excited repulsed 1.214285714
# uncertain offended 2.266666667
# disappointed awed 0.461538462
# upset sad 8.615384615
# anxious apprehensive 8.928571429
# disbelieving concerned 4.733333333
# satisfied delighted 7.6

# %%
with open('roberta_layer8_CC_ab_FEvocab.txt', newline='') as embeddings:
    embeddings_reader = csv.reader(embeddings, delimiter=' ')
    for row in embeddings_reader:
        word, val_one, val_two = row[0:3]
        print(len(row))
        print(word, val_one, val_two)
# Out:
# 769
# stupefied 0.03810151666402817 0.4511721730232239
# 769
# scornful 0.1777297705411911 0.2063738852739334
# 769
# disbelieving 0.06327465921640396 0.3719221353530884
# 769
# disdainful 0.14065775275230408 0.17121557891368866
# 769
# revolted 0.17597739398479462 0.2430000901222229
# 769
# miffed 0.05793330818414688 0.622585654258728
# 769
# aghast 0.04707120731472969 0.1249726265668869
# 769
# incensed 0.10659680515527725 0.4176652133464813
# 769
# dejected 0.1474914252758026 0.38218551874160767
# 769
# repulsed 0.1795245110988617 0.5356304049491882
# 769
# mournful 0.18566730618476868 0.6341727375984192
# 769
# displeased 0.06095200031995773 0.5087634921073914
# 769
# infuriated 0.2973356246948242 0.546241283416748
# 769
# awed 0.25107261538505554 0.4691216051578522
# 769
# repelled 0.0305007454007864 0.524250864982605
# 769
# resentful 0.009091274812817574 -0.008461663499474525
# 769
# sorrowful 0.2454274594783783 0.48665356636047363
# 769
# irate 0.07118450850248337 0.7552899122238159
# 769
# dismayed 0.12123062461614609 0.35746288299560547
# 769
# elated 0.23875682055950165 0.8242834210395813
# 769
# enraged 0.10765265673398972 0.1411270946264267
# 769
# apprehensive 0.2101047784090042 0.1849362552165985
# 769
# bewildered -0.09369037300348282 0.29490068554878235
# 769
# astounded 0.13150052726268768 0.4883606731891632
# 769
# perplexed 0.08382019400596619 0.39609378576278687
# 769
# appalled 0.05587070807814598 0.13275830447673798
# 769
# startled 0.14057305455207825 0.24218332767486572
# 769
# astonished 0.1551758497953415 0.3363286554813385
# 769
# alarmed 0.042763419449329376 0.14053408801555634
# 769
# outraged 0.07327248901128769 -0.09987881779670715
# 769
# disgusted 0.02836512215435505 -0.24894465506076813
# 769
# doubtful 0.09195797890424728 0.1748138815164566
# 769
# dissatisfied -0.05361471697688103 0.47706449031829834
# 769
# saddened 0.17261534929275513 0.2731105089187622
# 769
# irritated 0.0863291472196579 0.3508131802082062
# 769
# amused -0.045611925423145294 0.7749844193458557
# 769
# frightened 0.11484578251838684 -0.030251583084464073
# 769
# discouraged -0.006787125952541828 0.6045856475830078
# 769
# stunned 0.03710363060235977 0.0813526138663292
# 769
# fearful 0.06463435292243958 -0.47089582681655884
# 769
# pissed 0.08302333205938339 0.13040848076343536
# 769
# terrified 0.20234373211860657 -0.376444935798645
# 769
# offended -0.004602809902280569 0.24108336865901947
# 769
# annoyed -0.0017347687389701605 0.4170282483100891
# 769
# skeptical 0.1025649756193161 0.3615456819534302
# 769
# hostile 0.09378793835639954 0.10953228175640106
# 769
# furious 0.025623086839914322 0.3491320312023163
# 769
# bothered 0.20623444020748138 0.6412208080291748
# 769
# joyful 0.09031761437654495 0.9501411318778992
# 769
# uncertain 0.10660417377948761 0.1203695684671402
# 769
# cheerful 0.07360648363828659 0.7768300175666809
# 769
# depressed 0.10679991543292999 0.5627831816673279
# 769
# anxious 0.03022199124097824 0.20521165430545807
# 769
# frustrated -0.06477090716362 0.45463085174560547
# 769
# distressed 0.2576792538166046 0.5713441371917725
# 769
# bored -0.272273451089859 -0.09515327960252762
# 769
# suspicious 0.056330371648073196 0.2563183605670929
# 769
# shocked 0.06059930846095085 0.08255539834499359
# 769
# amazed 0.19568805396556854 0.4719496965408325
# 769
# rejected -0.037142835557460785 -0.021383194252848625
# 769
# disappointed -0.006761046126484871 0.18120746314525604
# 769
# upset 0.06363674998283386 0.5702461004257202
# 769
# delighted 0.005706502124667168 0.5543569326400757
# 769
# scared 0.13776549696922302 -0.3612149953842163
# 769
# worried -0.02576100081205368 0.3485371172428131
# 769
# confused -0.006843282841145992 0.31440550088882446
# 769
# neutral 0.19832077622413635 0.27167025208473206
# 769
# angry -0.08520569652318954 0.03125316649675369
# 769
# satisfied 0.08473800867795944 0.4837902784347534
# 769
# surprised 0.07068602740764618 0.3669273555278778
# 769
# pleased 0.16051317751407623 0.8066999316215515
# 769
# concerned -0.08922310173511505 0.48089510202407837
# 769
# mad 0.04878701642155647 0.5441299080848694
# 769
# hurt 0.118600994348526 0.18369930982589722
# 769
# excited 0.0871216207742691 0.6767975091934204
# 769
# sad 0.21352700889110565 0.48791056871414185
# 769
# interested -0.10697963088750839 0.3963739275932312
# 769
# happy 0.11767317354679108 0.826087474822998

# %%
embeddings_dict = {}
with open('roberta_layer8_CC_ab_FEvocab.txt', newline='') as embeddings:
    embeddings_reader = csv.reader(embeddings, delimiter=' ')
    for row in embeddings_reader:
        embeddings_dict[row[0]] = row[1:]

# %%
print(len(embeddings_dict["dejected"]))
# Out:
# 768

# %%
train_pair = []
train_score = []
with open('FE_pairs_human_rater_scores_nodupes_train.csv', newline='', encoding='utf-8-sig') as train:
    train_reader = csv.reader(train, delimiter=',')
    for row in train_reader:
        word_one, word_two, score = row[0], row[1], row[2]
#         np_one = np.array(embeddings_dict[word_one]).astype(np.float64)
#         np_two = np.array(embeddings_dict[word_two]).astype(np.float64)
        print(word_one, word_two, score)
        np.append(train_pair, np_one, np_two)
        train_score.append(score)
# Out:
# disdainful excited 0.571428571
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-107-b3d85e51c3ed> in <module>
#       8         np_two = np.array(embeddings_dict[word_two]).astype(np.float64)
#       9         print(word_one, word_two, score)
# ---> 10         np.append(train_pair, np_one, np_two)
#      11         train_score.append(score)
#
# <__array_function__ internals> in append(*args, **kwargs)
#
# ~/Documents/Code_Projects/NLP/venv/lib/python3.7/site-packages/numpy/lib/function_base.py in append(arr, values, axis)
#    4691         values = ravel(values)
#    4692         axis = arr.ndim-1
# -> 4693     return concatenate((arr, values), axis=axis)
#    4694
#    4695
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# TypeError: only integer scalar arrays can be converted to a scalar index

# %%
493324279785', '-0.3353155255317688', '-0.49425357580184937', '0.06691092997789383', '0.05080188065767288', '-0.29626229405403137', '-0.6441211700439453', '-0.6464097499847412', '0.1395629495382309', '-0.0662878006696701', '-0.1876824051141739', '0.1365453600883484', '-0.15835630893707275', '0.5466534495353699', '-0.3487355411052704', '0.37828725576400757', '0.47793835401535034', '0.17022490501403809', '-0.13605746626853943', '-0.38947582244873047', '1.0783543586730957', '-0.044013626873493195', '0.1364191174507141', '0.07521460205316544', '0.1808399260044098', '-0.16101281344890594', '0.13818058371543884', '-0.33883002400398254', '0.4547559320926666', '-0.31543105840682983', '-0.32605689764022827', '-0.09478788822889328', '-0.013605523854494095', '-0.32474321126937866', '-0.43547573685646057', '0.6221575140953064', '-0.19798733294010162', '-0.09092479199171066', '0.38617366552352905', '0.23965030908584595', '-0.35841280221939087', '0.06771256774663925', '-0.05281657353043556', '-0.3640880882740021', '0.1261751502752304', '-1.2716193199157715', '0.4721479117870331', '0.20711848139762878', '-0.012512288987636566', '-0.12339591979980469', '0.27841195464134216', '-0.3151797652244568', '0.19796565175056458', '0.14651617407798767', '-0.5743550062179565', '0.26003536581993103', '0.9650718569755554', '-0.1212654709815979', '-0.34265363216400146', '0.06934260576963425', '0.2025446742773056', '0.15738718211650848', '0.21646185219287872', '-0.06996512413024902', '0.030026689171791077', '0.1996062695980072', '0.007282455917447805', '0.48878806829452515', '-0.15115633606910706', '0.5599915981292725', '-0.10919483751058578', '-0.009878117591142654', '0.5837652087211609', '-0.49998369812965393', '0.41502127051353455', '0.011143090203404427', '0.13669000566005707', '0.43480390310287476', '-0.6074970960617065', '0.1597665697336197', '1.7032567262649536', '0.040400225669145584', '0.22772349417209625', '0.021695047616958618', '0.7313269972801208', '0.15488757193088531', '0.23862192034721375', '0.052616413682699203', '0.25747570395469666', '0.08447969704866409', '0.09459954500198364', '0.06619524210691452', '-1.0249226093292236', '0.2053215205669403', '-0.3537963330745697', '0.33936578035354 ...

# %%
np_train_pair = np.array(train_pair)

# %%
np_train_score = np.array(train_score)

# %%
reg = LinearRegression().fit(train_pair, np_train_score)
# Out:
# /Users/crystal.butler/Documents/Code_Projects/NLP/venv/lib/python3.7/site-packages/sklearn/utils/validation.py:73: FutureWarning: Beginning in version 0.22, arrays of bytes/strings will be converted to decimal numbers if dtype='numeric'. It is recommended that you convert the array to a float dtype before using it in scikit-learn, for example by using your_array = your_array.astype(np.float64).
#   return f(**kwargs)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-97-fffbf0f259ae> in <module>
# ----> 1 reg = LinearRegression().fit(train_pair, np_train_score)
#
# ~/Documents/Code_Projects/NLP/venv/lib/python3.7/site-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     504         n_jobs_ = self.n_jobs
#     505         X, y = self._validate_data(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 506                                    y_numeric=True, multi_output=True)
#     507
#     508         if sample_weight is not None:
#
# ~/Documents/Code_Projects/NLP/venv/lib/python3.7/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# --> 432                 X, y = check_X_y(X, y, **check_params)
#     433             out = X, y
#     434
#
# ~/Documents/Code_Projects/NLP/venv/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~/Documents/Code_Projects/NLP/venv/lib/python3.7/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     801                     ensure_min_samples=ensure_min_samples,
#     802                     ensure_min_features=ensure_min_features,
# --> 803                     estimator=estimator)
#     804     if multi_output:
#     805         y = check_array(y, accept_sparse='csr', force_all_finite=True,
#
# ~/Documents/Code_Projects/NLP/venv/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~/Documents/Code_Projects/NLP/venv/lib/python3.7/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     640         if not allow_nd and array.ndim >= 3:
#     641             raise ValueError("Found array with dim %d. %s expected <= 2."
# --> 642                              % (array.ndim, estimator_name))
#     643
#     644         if force_all_finite:
#
# ValueError: Found array with dim 3. Estimator expected <= 2.
